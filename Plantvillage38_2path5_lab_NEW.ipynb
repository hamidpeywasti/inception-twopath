# %% [markdown]
# <a href="https://colab.research.google.com/github/hamidpeywasti/inception-twopath/blob/main/Plantvillage38_2path5_lab_NEW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
monitor='val_accuracy'
epochs=70
batch_size=32
input_shape=(224, 224, 3) # please resize it to (224,224,3) if you have enough RAM
Verbose=True

# %%
import sys
print("Python version:", sys.version)

import skimage
print('skimage:',  skimage.__version__)

import tensorflow as tf
print('Tensorflow:',tf.__version__)

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model

import multiprocessing

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.utils import class_weight

import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Python version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# skimage: 0.19.3
# Tensorflow: 2.15.0

# %%
#apt-get install git python3-opencv
import os

if not os.path.isdir('k'):
  # !git clone https://github.com/hamidpeywasti/keras-neural-api k
else:
  # !cd k && git pull

# !cd k && pip install .

# !rm -rf k

import cai
import cai.datasets
import cai.models
import cai.inception_v3
import cai.layers
import cai.util
from cai.layers import conv2d_bn
# Out:
# Cloning into 'k'...
# remote: Enumerating objects: 1809, done.
# remote: Counting objects: 100% (221/221), done.
# remote: Compressing objects: 100% (144/144), done.
# remote: Total 1809 (delta 135), reused 147 (delta 72), pack-reused 1588
# Receiving objects: 100% (1809/1809), 15.69 MiB | 36.10 MiB/s, done.
# Resolving deltas: 100% (1248/1248), done.
# Processing /content/k
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from cai==0.1.7) (1.5.3)
# Requirement already satisfied: scikit-image>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from cai==0.1.7) (0.19.3)
# Requirement already satisfied: opencv-python>=4.1.2.30 in /usr/local/lib/python3.10/dist-packages (from cai==0.1.7) (4.8.0.76)
# Requirement already satisfied: scikit-learn>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from cai==0.1.7) (1.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from cai==0.1.7) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.22.0->cai==0.1.7) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.22.0->cai==0.1.7) (2023.3.post1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.15.0->cai==0.1.7) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.15.0->cai==0.1.7) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.15.0->cai==0.1.7) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.15.0->cai==0.1.7) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.15.0->cai==0.1.7) (2023.12.9)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.15.0->cai==0.1.7) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.15.0->cai==0.1.7) (23.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.0->cai==0.1.7) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.0->cai==0.1.7) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.22.0->cai==0.1.7) (1.16.0)
# Building wheels for collected packages: cai
#   Building wheel for cai (setup.py) ... done
#   Created wheel for cai: filename=cai-0.1.7-py3-none-any.whl size=61388 sha256=951b1b238cb47ff6a8f59e098cf434b8211374a2d46cee0f2a680ac29c285ff6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-15yo8k_s/wheels/80/61/f5/947bedc7e497038def7d1381fb65d37bd126a80e010114b8f1
# Successfully built cai
# Installing collected packages: cai
#   Attempting uninstall: cai
#     Found existing installation: cai 0.1.7
#     Uninstalling cai-0.1.7:
#       Successfully uninstalled cai-0.1.7
# Successfully installed cai-0.1.7

# %%
def two_path5_inception_v5(
                include_top=True,
                weights=None, #'two_paths_plant_leafs'
                input_shape=(224,224,3),
                pooling=None,
                classes=1000,
                two_paths=False,
                deep_two_paths=False,
                deep_two_paths_compression=0.655,
                deep_two_paths_bottleneck_compression=0.5,
                l_ratio=0.5,
                ab_ratio=0.5,
                max_mix_idx=10,
                max_mix_deep_two_paths_idx=-1,
                model_name='two_path_inception_v3',
                kType=0,
                **kwargs):
    """
    Instantiates the Inception v3 architecture with 2 paths options.
    """
    img_input = keras.layers.Input(shape=input_shape)
    if (deep_two_paths):  max_mix_deep_two_paths_idx = max_mix_idx

    if keras.backend.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = 3


    if two_paths:
        if (l_ratio>0):
            l_branch = cai.layers.CopyChannels(0,1)(img_input)
            l_branch = conv2d_bn(l_branch, int(round(32*l_ratio)), 3, 3, strides=(2, 2), padding='valid')
            l_branch = conv2d_bn(l_branch, int(round(32*l_ratio)), 3, 3, padding='valid')
            l_branch = conv2d_bn(l_branch, int(round(64*l_ratio)), 3, 3)
            l_branch = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(l_branch)

            l_branch = conv2d_bn(l_branch, int(round(80*l_ratio)), 1, 1, padding='valid')
            l_branch = conv2d_bn(l_branch, int(round(192*l_ratio)), 3, 3, padding='valid')

        if (ab_ratio>0):
            ab_branch = cai.layers.CopyChannels(1,2)(img_input)
            ab_branch = conv2d_bn(ab_branch, int(round(32*ab_ratio)), 3, 3, strides=(2, 2), padding='valid')
            ab_branch = conv2d_bn(ab_branch, int(round(32*ab_ratio)), 3, 3, padding='valid')
            ab_branch = conv2d_bn(ab_branch, int(round(64*ab_ratio)), 3, 3)
            ab_branch = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(ab_branch)

            ab_branch = conv2d_bn(ab_branch, int(round(80*ab_ratio)), 1, 1, padding='valid')
            ab_branch = conv2d_bn(ab_branch, int(round(192*ab_ratio)), 3, 3, padding='valid')

        if (l_ratio>0):
            if (ab_ratio>0):
                x = keras.layers.Concatenate(axis=channel_axis, name='concat_first_block')([l_branch, ab_branch])
            else:
                x = l_branch
        else:
            x = ab_branch
    else:
        single_branch = conv2d_bn(img_input, 32, 3, 3, strides=(2, 2), padding='valid')
        single_branch = conv2d_bn(single_branch, 32, 3, 3, padding='valid')
        single_branch = conv2d_bn(single_branch, 64, 3, 3)
        single_branch = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(single_branch)

        # x = conv2d_bn(x, 80, 1, 1, padding='valid')
        x = cai.inception_v3.kInceptionPointwise(single_branch, filters=80, name='single_path', kType=kType)
        x = conv2d_bn(single_branch, 192, 3, 3, padding='valid')

    x = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(x)

    if max_mix_idx >= 0:
        for id_layer in range(max_mix_idx+1):
            if (max_mix_deep_two_paths_idx >= id_layer):
                x = cai.inception_v3.create_inception_v3_two_path_mixed_layer(x,  id=id_layer,  name='mixed'+str(id_layer),
                    channel_axis=channel_axis, bottleneck_compression=deep_two_paths_bottleneck_compression,
                    compression=deep_two_paths_compression, has_batch_norm=True, kType=kType)
            else:
                x = cai.inception_v3.create_inception_v3_mixed_layer(x,  id=id_layer,  name='mixed'+str(id_layer), channel_axis=channel_axis, kType=kType)

    if include_top:
        # Classification block
        x = keras.layers.GlobalAveragePooling2D(name='avg_pool')(x)
        x = keras.layers.Dense(classes, activation='softmax', name='predictions')(x)
    else:
        if pooling == 'avg':
            x = keras.layers.GlobalAveragePooling2D()(x)
        elif pooling == 'max':
            x = keras.layers.GlobalMaxPooling2D()(x)

    inputs = img_input
    # Create model.
    model = keras.models.Model(inputs, x, name=model_name)
    return model

def plot_history(filename):
    plt.figure(figsize=(10, 6))

    # Plot training & validation loss values
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'], loc='upper right')
    plt.ylim(ymin=0, ymax=1.5)

    # Plot training & validation accuracy values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'], loc='lower right')

    plt.savefig(filename)

    plt.tight_layout()
    plt.show()

def top_k_accuracy(y_true, y_pred, k=5):
    """
    Calculate top-k accuracy.

    Parameters:
    - y_true: True labels (ground truth)
    - y_pred: Predicted labels (probabilities or scores)
    - k: Top-k value (default is 5)

    Returns:
    - Top-k accuracy
    """
    top_k = np.argsort(y_pred, axis=-1)[:, -k:]
    correct = np.argmax(y_true, axis=-1)
    matches = np.any(top_k == correct[:, np.newaxis], axis=-1)
    accuracy = np.mean(matches)
    return accuracy

# %% [markdown]
# # Loading Data

# %%
url_zip_file="https://data.mendeley.com/datasets/tywbtsjrjv/1/files/d5652a28-c1d8-4b76-97f3-72fb80f94efc/Plant_leaf_diseases_dataset_without_augmentation.zip?dl=1"
local_zip_file="plant_leaf.zip"
expected_folder_name="plant_leaf"
Verbose=True
cai.datasets.download_zip_and_extract(
    url_zip_file=url_zip_file, local_zip_file=local_zip_file,
    expected_folder_name=expected_folder_name, Verbose=Verbose)
# Out:
# Downloading:  https://data.mendeley.com/datasets/tywbtsjrjv/1/files/d5652a28-c1d8-4b76-97f3-72fb80f94efc/Plant_leaf_diseases_dataset_without_augmentation.zip?dl=1  to  plant_leaf.zip
# Decompressing into:  plant_leaf

# %%
# !rm -r plant_leaf/Plant_leave_diseases_dataset_without_augmentation/Background_without_leaves -R

# %%
data_dir = "plant_leaf/Plant_leave_diseases_dataset_without_augmentation/"

label_of_classes = os.listdir(data_dir)
print("Classes Lables:", label_of_classes)

number_of_classes = len(label_of_classes)
print("Number of Classes:", number_of_classes)

train_x, val_x, test_x, train_y, val_y, test_y, classweight, classes = cai.datasets.load_images_from_folders(
    seed=7,
    root_dir=data_dir,
    lab=True,
    verbose=Verbose,
    bipolar=False,
    base_model_name='plant_leaf',
    training_size=0.6,
    validation_size=0.2,
    test_size=0.2,
    target_size=(input_shape[0],input_shape[1]),
    has_training=True,
    has_validation=True,
    has_testing=True,
    smart_resize=True
)

print(train_x.shape,val_x.shape,test_x.shape)
print(train_y.shape,val_y.shape,test_y.shape)
# Out:
# Classes Lables: ['Tomato___Septoria_leaf_spot', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Late_blight', 'Tomato___Tomato_mosaic_virus', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Corn___Common_rust', 'Corn___healthy', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___Black_rot', 'Apple___Cedar_apple_rust', 'Potato___healthy', 'Cherry___healthy', 'Tomato___Bacterial_spot', 'Orange___Haunglongbing_(Citrus_greening)', 'Grape___healthy', 'Peach___healthy', 'Cherry___Powdery_mildew', 'Pepper,_bell___healthy', 'Peach___Bacterial_spot', 'Grape___Esca_(Black_Measles)', 'Apple___Apple_scab', 'Tomato___Early_blight', 'Tomato___Target_Spot', 'Corn___Cercospora_leaf_spot Gray_leaf_spot', 'Potato___Late_blight', 'Soybean___healthy', 'Tomato___Leaf_Mold', 'Apple___healthy', 'Potato___Early_blight', 'Tomato___healthy', 'Blueberry___healthy', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Pepper,_bell___Bacterial_spot', 'Corn___Northern_Leaf_Blight', 'Raspberry___healthy', 'Apple___Black_rot', 'Squash___Powdery_mildew']
# Number of Classes: 38
# Loading  38  classes.
# smart resize is enabled.
# loading train images

# %% [markdown]
# # Fitting Model for L_ratio and AB_ratio

# %%
for l_ratio in [0.25,0.50]:

        basefilename = 'Apple13-2Path5-NEW-LAB-m4-' + str(l_ratio)
        print('Running: '+basefilename)

        model = two_path5_inception_v5(
            include_top=True,
            weights=None,
            input_tensor=None,
            input_shape=input_shape,
            two_paths=True,
            pooling='max',
            classes=number_of_classes,
            l_ratio=l_ratio,
            ab_ratio=(1.0-l_ratio),
            max_mix_idx=4
        )

        model.compile(
            loss='categorical_crossentropy',
            optimizer=keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True),
            metrics=['accuracy']
        )

        best_result_file_name = basefilename+'-best_result.hdf5'

        save_best = tf.keras.callbacks.ModelCheckpoint(
            filepath=best_result_file_name,
            monitor=monitor,
            verbose=True,
            save_best_only=True,
            save_weights_only=False,
            mode='max',
            save_freq='epoch'
        )

        history = model.fit(
            train_x,
            train_y,
            epochs=120,
            batch_size=batch_size,
            validation_data=(val_x,val_y),
            callbacks=[save_best],
            class_weight=classweight,
            workers=multiprocessing.cpu_count()
        )

        history_filename = basefilename +'-History.png'
        plot_history(history_filename)

        print('Testing Last Model: '+basefilename)

        evaluated = model.evaluate(test_x,test_y)

        for metric, name in zip(evaluated,["loss","acc"]):
            print(name,metric)

        # print('Best Model Results: '+basefilename)

        # model = tf.keras.models.load_model(
        #     best_result_file_name,
        #     custom_objects={'CopyChannels': cai.layers.CopyChannels}
        # )

        evaluated = model.evaluate(test_x,test_y)

        # cai.models.save_model(model, basefilename)

        # for metric, name in zip(evaluated,["loss","acc","top 5 acc"]):
        #     print(name,metric)

        print('Finished: '+basefilename)
# Out:
# Running: Apple13-2Path5-NEW-LAB-m4-0.25
# Epoch 1/120
# 1018/1018 [==============================] - ETA: 0s - loss: 0.8876 - accuracy: 0.7340
# Epoch 1: val_accuracy improved from -inf to 0.54955, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1018/1018 [==============================] - 70s 55ms/step - loss: 0.8876 - accuracy: 0.7340 - val_loss: 1.9821 - val_accuracy: 0.5495
# Epoch 2/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.2917 - accuracy: 0.9007
# Epoch 2: val_accuracy improved from 0.54955 to 0.69147, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.2916 - accuracy: 0.9007 - val_loss: 1.1488 - val_accuracy: 0.6915
# Epoch 3/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.1810 - accuracy: 0.9365
# Epoch 3: val_accuracy improved from 0.69147 to 0.82428, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.1810 - accuracy: 0.9365 - val_loss: 0.5608 - val_accuracy: 0.8243
# Epoch 4/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.1258 - accuracy: 0.9535
# Epoch 4: val_accuracy improved from 0.82428 to 0.93535, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.1258 - accuracy: 0.9535 - val_loss: 0.1881 - val_accuracy: 0.9353
# Epoch 5/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0941 - accuracy: 0.9653
# Epoch 5: val_accuracy did not improve from 0.93535
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0941 - accuracy: 0.9653 - val_loss: 0.3666 - val_accuracy: 0.8918
# Epoch 6/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0757 - accuracy: 0.9726
# Epoch 6: val_accuracy did not improve from 0.93535
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0757 - accuracy: 0.9726 - val_loss: 0.8076 - val_accuracy: 0.7794
# Epoch 7/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0603 - accuracy: 0.9781
# Epoch 7: val_accuracy did not improve from 0.93535
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0602 - accuracy: 0.9781 - val_loss: 0.2338 - val_accuracy: 0.9260
# Epoch 8/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0562 - accuracy: 0.9807
# Epoch 8: val_accuracy improved from 0.93535 to 0.94796, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0562 - accuracy: 0.9806 - val_loss: 0.1532 - val_accuracy: 0.9480
# Epoch 9/120
# 1018/1018 [==============================] - ETA: 0s - loss: 0.0389 - accuracy: 0.9855
# Epoch 9: val_accuracy improved from 0.94796 to 0.97136, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0389 - accuracy: 0.9855 - val_loss: 0.0883 - val_accuracy: 0.9714
# Epoch 10/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9884
# Epoch 10: val_accuracy did not improve from 0.97136
# 1018/1018 [==============================] - 41s 40ms/step - loss: 0.0321 - accuracy: 0.9885 - val_loss: 0.2218 - val_accuracy: 0.9290
# Epoch 11/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0409 - accuracy: 0.9852
# Epoch 11: val_accuracy improved from 0.97136 to 0.97651, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0409 - accuracy: 0.9852 - val_loss: 0.0732 - val_accuracy: 0.9765
# Epoch 12/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9924
# Epoch 12: val_accuracy did not improve from 0.97651
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0206 - accuracy: 0.9924 - val_loss: 0.1588 - val_accuracy: 0.9481
# Epoch 13/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0182 - accuracy: 0.9940
# Epoch 13: val_accuracy did not improve from 0.97651
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0182 - accuracy: 0.9940 - val_loss: 0.0751 - val_accuracy: 0.9761
# Epoch 14/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0200 - accuracy: 0.9935
# Epoch 14: val_accuracy improved from 0.97651 to 0.98186, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.0585 - val_accuracy: 0.9819
# Epoch 15/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0230 - accuracy: 0.9923
# Epoch 15: val_accuracy did not improve from 0.98186
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0230 - accuracy: 0.9924 - val_loss: 0.1017 - val_accuracy: 0.9660
# Epoch 16/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0238 - accuracy: 0.9917
# Epoch 16: val_accuracy did not improve from 0.98186
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0238 - accuracy: 0.9917 - val_loss: 0.0889 - val_accuracy: 0.9727
# Epoch 17/120
# 1018/1018 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9938
# Epoch 17: val_accuracy improved from 0.98186 to 0.98600, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0171 - accuracy: 0.9938 - val_loss: 0.0510 - val_accuracy: 0.9860
# Epoch 18/120
# 1018/1018 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9960
# Epoch 18: val_accuracy improved from 0.98600 to 0.98683, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0129 - accuracy: 0.9960 - val_loss: 0.0446 - val_accuracy: 0.9868
# Epoch 19/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0120 - accuracy: 0.9961
# Epoch 19: val_accuracy improved from 0.98683 to 0.98720, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.0420 - val_accuracy: 0.9872
# Epoch 20/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 0.9966
# Epoch 20: val_accuracy improved from 0.98720 to 0.99309, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0091 - accuracy: 0.9966 - val_loss: 0.0251 - val_accuracy: 0.9931
# Epoch 21/120
# 1018/1018 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9960
# Epoch 21: val_accuracy did not improve from 0.99309
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 0.1136 - val_accuracy: 0.9681
# Epoch 22/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9980
# Epoch 22: val_accuracy did not improve from 0.99309
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0073 - accuracy: 0.9980 - val_loss: 0.0268 - val_accuracy: 0.9929
# Epoch 23/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0054 - accuracy: 0.9983
# Epoch 23: val_accuracy did not improve from 0.99309
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0446 - val_accuracy: 0.9874
# Epoch 24/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.9988
# Epoch 24: val_accuracy did not improve from 0.99309
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0284 - val_accuracy: 0.9926
# Epoch 25/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 0.9981
# Epoch 25: val_accuracy did not improve from 0.99309
# 1018/1018 [==============================] - 41s 40ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.1069 - val_accuracy: 0.9675
# Epoch 26/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0047 - accuracy: 0.9982
# Epoch 26: val_accuracy did not improve from 0.99309
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0047 - accuracy: 0.9982 - val_loss: 0.0390 - val_accuracy: 0.9898
# Epoch 27/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 0.9986
# Epoch 27: val_accuracy did not improve from 0.99309
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.1200 - val_accuracy: 0.9618
# Epoch 28/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0107 - accuracy: 0.9970
# Epoch 28: val_accuracy did not improve from 0.99309
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0107 - accuracy: 0.9970 - val_loss: 0.0875 - val_accuracy: 0.9763
# Epoch 29/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9973
# Epoch 29: val_accuracy improved from 0.99309 to 0.99383, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0244 - val_accuracy: 0.9938
# Epoch 30/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0037 - accuracy: 0.9991
# Epoch 30: val_accuracy improved from 0.99383 to 0.99484, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0237 - val_accuracy: 0.9948
# Epoch 31/120
# 1018/1018 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9989
# Epoch 31: val_accuracy did not improve from 0.99484
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0220 - val_accuracy: 0.9944
# Epoch 32/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0037 - accuracy: 0.9990
# Epoch 32: val_accuracy improved from 0.99484 to 0.99512, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.0198 - val_accuracy: 0.9951
# Epoch 33/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9993
# Epoch 33: val_accuracy improved from 0.99512 to 0.99549, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0192 - val_accuracy: 0.9955
# Epoch 34/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0016 - accuracy: 0.9997
# Epoch 34: val_accuracy improved from 0.99549 to 0.99567, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0179 - val_accuracy: 0.9957
# Epoch 35/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 35: val_accuracy did not improve from 0.99567
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0198 - val_accuracy: 0.9953
# Epoch 36/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9983
# Epoch 36: val_accuracy did not improve from 0.99567
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0041 - accuracy: 0.9983 - val_loss: 0.0208 - val_accuracy: 0.9953
# Epoch 37/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.9978
# Epoch 37: val_accuracy did not improve from 0.99567
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.0554 - val_accuracy: 0.9835
# Epoch 38/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9990
# Epoch 38: val_accuracy did not improve from 0.99567
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.0237 - val_accuracy: 0.9945
# Epoch 39/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0057 - accuracy: 0.9982
# Epoch 39: val_accuracy did not improve from 0.99567
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.0241 - val_accuracy: 0.9933
# Epoch 40/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9995
# Epoch 40: val_accuracy did not improve from 0.99567
# 1018/1018 [==============================] - 41s 41ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0175 - val_accuracy: 0.9957
# Epoch 41/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9995
# Epoch 41: val_accuracy did not improve from 0.99567
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0202 - val_accuracy: 0.9946
# Epoch 42/120
# 1018/1018 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9984
# Epoch 42: val_accuracy did not improve from 0.99567
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.0672 - val_accuracy: 0.9827
# Epoch 43/120
# 1018/1018 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9994
# Epoch 43: val_accuracy did not improve from 0.99567
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0188 - val_accuracy: 0.9950
# Epoch 44/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9994
# Epoch 44: val_accuracy did not improve from 0.99567
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0167 - val_accuracy: 0.9956
# Epoch 45/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9993
# Epoch 45: val_accuracy did not improve from 0.99567
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0240 - val_accuracy: 0.9938
# Epoch 46/120
# 1018/1018 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9995
# Epoch 46: val_accuracy improved from 0.99567 to 0.99632, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0176 - val_accuracy: 0.9963
# Epoch 47/120
# 1018/1018 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 47: val_accuracy did not improve from 0.99632
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0160 - val_accuracy: 0.9959
# Epoch 48/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9995
# Epoch 48: val_accuracy did not improve from 0.99632
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0200 - val_accuracy: 0.9948
# Epoch 49/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 9.9766e-04 - accuracy: 0.9999
# Epoch 49: val_accuracy did not improve from 0.99632
# 1018/1018 [==============================] - 42s 41ms/step - loss: 9.9720e-04 - accuracy: 0.9999 - val_loss: 0.0196 - val_accuracy: 0.9949
# Epoch 50/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9997
# Epoch 50: val_accuracy did not improve from 0.99632
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0179 - val_accuracy: 0.9958
# Epoch 51/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0014 - accuracy: 0.9997
# Epoch 51: val_accuracy improved from 0.99632 to 0.99641, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0173 - val_accuracy: 0.9964
# Epoch 52/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 9.5990e-04 - accuracy: 0.9999
# Epoch 52: val_accuracy did not improve from 0.99641
# 1018/1018 [==============================] - 42s 41ms/step - loss: 9.6089e-04 - accuracy: 0.9999 - val_loss: 0.0180 - val_accuracy: 0.9958
# Epoch 53/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 8.3050e-04 - accuracy: 0.9999
# Epoch 53: val_accuracy did not improve from 0.99641
# 1018/1018 [==============================] - 42s 41ms/step - loss: 8.2987e-04 - accuracy: 0.9999 - val_loss: 0.0169 - val_accuracy: 0.9963
# Epoch 54/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 7.4838e-04 - accuracy: 0.9998
# Epoch 54: val_accuracy did not improve from 0.99641
# 1018/1018 [==============================] - 42s 41ms/step - loss: 7.4795e-04 - accuracy: 0.9998 - val_loss: 0.0173 - val_accuracy: 0.9961
# Epoch 55/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9996
# Epoch 55: val_accuracy did not improve from 0.99641
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0160 - val_accuracy: 0.9960
# Epoch 56/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 56: val_accuracy improved from 0.99641 to 0.99650, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0150 - val_accuracy: 0.9965
# Epoch 57/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 9.7374e-04 - accuracy: 0.9998
# Epoch 57: val_accuracy did not improve from 0.99650
# 1018/1018 [==============================] - 42s 41ms/step - loss: 9.7315e-04 - accuracy: 0.9998 - val_loss: 0.0221 - val_accuracy: 0.9952
# Epoch 58/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 8.7513e-04 - accuracy: 0.9998
# Epoch 58: val_accuracy did not improve from 0.99650
# 1018/1018 [==============================] - 42s 41ms/step - loss: 8.7453e-04 - accuracy: 0.9998 - val_loss: 0.0172 - val_accuracy: 0.9963
# Epoch 59/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9998
# Epoch 59: val_accuracy did not improve from 0.99650
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0218 - val_accuracy: 0.9948
# Epoch 60/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9994
# Epoch 60: val_accuracy did not improve from 0.99650
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0285 - val_accuracy: 0.9932
# Epoch 61/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 61: val_accuracy did not improve from 0.99650
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0203 - val_accuracy: 0.9956
# Epoch 62/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 9.0442e-04 - accuracy: 0.9999
# Epoch 62: val_accuracy did not improve from 0.99650
# 1018/1018 [==============================] - 42s 41ms/step - loss: 9.0380e-04 - accuracy: 0.9999 - val_loss: 0.0170 - val_accuracy: 0.9963
# Epoch 63/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 9.1441e-04 - accuracy: 0.9998
# Epoch 63: val_accuracy did not improve from 0.99650
# 1018/1018 [==============================] - 42s 41ms/step - loss: 9.1377e-04 - accuracy: 0.9998 - val_loss: 0.0163 - val_accuracy: 0.9963
# Epoch 64/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 5.2936e-04 - accuracy: 0.9999
# Epoch 64: val_accuracy did not improve from 0.99650
# 1018/1018 [==============================] - 42s 41ms/step - loss: 5.2904e-04 - accuracy: 0.9999 - val_loss: 0.0158 - val_accuracy: 0.9965
# Epoch 65/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 4.4740e-04 - accuracy: 1.0000
# Epoch 65: val_accuracy did not improve from 0.99650
# 1018/1018 [==============================] - 42s 41ms/step - loss: 4.4731e-04 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 0.9961
# Epoch 66/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 6.1254e-04 - accuracy: 0.9999
# Epoch 66: val_accuracy improved from 0.99650 to 0.99687, saving model to Apple13-2Path5-NEW-LAB-m4-0.25-best_result.hdf5
# 1018/1018 [==============================] - 42s 41ms/step - loss: 6.1207e-04 - accuracy: 0.9999 - val_loss: 0.0162 - val_accuracy: 0.9969
# Epoch 67/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 7.4535e-04 - accuracy: 0.9997
# Epoch 67: val_accuracy did not improve from 0.99687
# 1018/1018 [==============================] - 42s 41ms/step - loss: 7.4482e-04 - accuracy: 0.9997 - val_loss: 0.0190 - val_accuracy: 0.9956
# Epoch 68/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 7.7790e-04 - accuracy: 0.9998
# Epoch 68: val_accuracy did not improve from 0.99687
# 1018/1018 [==============================] - 42s 41ms/step - loss: 7.7761e-04 - accuracy: 0.9998 - val_loss: 0.0262 - val_accuracy: 0.9931
# Epoch 69/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 69: val_accuracy did not improve from 0.99687
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0160 - val_accuracy: 0.9963
# Epoch 70/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 4.5770e-04 - accuracy: 0.9999
# Epoch 70: val_accuracy did not improve from 0.99687
# 1018/1018 [==============================] - 42s 41ms/step - loss: 4.5735e-04 - accuracy: 0.9999 - val_loss: 0.0171 - val_accuracy: 0.9962
# Epoch 71/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 7.4479e-04 - accuracy: 0.9999
# Epoch 71: val_accuracy did not improve from 0.99687
# 1018/1018 [==============================] - 42s 41ms/step - loss: 7.4454e-04 - accuracy: 0.9999 - val_loss: 0.0165 - val_accuracy: 0.9959
# Epoch 72/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999
# Epoch 72: val_accuracy did not improve from 0.99687
# 1018/1018 [==============================] - 42s 41ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0223 - val_accuracy: 0.9948
# Epoch 73/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 4.9888e-04 - accuracy: 1.0000
# Epoch 73: val_accuracy did not improve from 0.99687
# 1018/1018 [==============================] - 42s 41ms/step - loss: 4.9871e-04 - accuracy: 1.0000 - val_loss: 0.0157 - val_accuracy: 0.9967
# Epoch 74/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 6.5869e-04 - accuracy: 0.9999
# Epoch 74: val_accuracy did not improve from 0.99687
# 1018/1018 [==============================] - 42s 41ms/step - loss: 6.5828e-04 - accuracy: 0.9999 - val_loss: 0.0182 - val_accuracy: 0.9961
# Epoch 75/120
# 1017/1018 [============================>.] - ETA: 0s - loss: 3.9332e-04 - accuracy: 1.0000
# Epoch 75: val_accuracy did not improve from 0.99687
# 1018/1018 [==============================] - 42s 41ms/step - loss: 3.9304e-04 - accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 0.9966
# Epoch 76/120
#  105/1018 [==>...........................] - ETA: 33s - loss: 7.0317e-04 - accuracy: 0.9997
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-c66761d74782> in <cell line: 1>()
#      35         )
#      36
# ---> 37         history = model.fit(
#      38             train_x,
#      39             train_y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1811                             logs = tmp_logs
#    1812                             end_step = step + data_handler.step_increment
# -> 1813                             callbacks.on_train_batch_end(end_step, logs)
#    1814                             if self.stop_training:
#    1815                                 break
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#     473         """
#     474         if self._should_call_train_batch_hooks:
# --> 475             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     476
#     477     def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     320             self._call_batch_begin_hook(mode, batch, logs)
#     321         elif hook == "end":
# --> 322             self._call_batch_end_hook(mode, batch, logs)
#     323         else:
#     324             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     343             self._batch_times.append(batch_time)
#     344
# --> 345         self._call_batch_hook_helper(hook_name, batch, logs)
#     346
#     347         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     391         for callback in self.callbacks:
#     392             hook = getattr(callback, hook_name)
# --> 393             hook(batch, logs)
#     394
#     395         if self._check_timing:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#    1091
#    1092     def on_train_batch_end(self, batch, logs=None):
# -> 1093         self._batch_update_progbar(batch, logs)
#    1094
#    1095     def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1167         if self.verbose == 1:
#    1168             # Only block async when verbose = 1.
# -> 1169             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1170             self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1171
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     692         return t.item() if np.ndim(t) == 0 else t
#     693
# --> 694     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     695
#     696
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     629     ValueError: If wrong keyword arguments are provided.
#     630   """
# --> 631   return nest_util.map_structure(
#     632       nest_util.Modality.CORE, func, *structure, **kwargs
#     633   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in map_structure(modality, func, *structure, **kwargs)
#    1064   """
#    1065   if modality == Modality.CORE:
# -> 1066     return _tf_core_map_structure(func, *structure, **kwargs)
#    1067   elif modality == Modality.DATA:
#    1068     return _tf_data_map_structure(func, *structure, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in _tf_core_map_structure(func, *structure, **kwargs)
#    1104   return _tf_core_pack_sequence_as(
#    1105       structure[0],
# -> 1106       [func(*x) for x in entries],
#    1107       expand_composites=expand_composites,
#    1108   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in <listcomp>(.0)
#    1104   return _tf_core_pack_sequence_as(
#    1105       structure[0],
# -> 1106       [func(*x) for x in entries],
#    1107       expand_composites=expand_composites,
#    1108   )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     685         # Don't turn ragged or sparse tensors to NumPy.
#     686         if isinstance(t, tf.Tensor):
# --> 687             t = t.numpy()
#     688         # Strings, ragged and sparse tensors don't have .item(). Return them
#     689         # as-is.
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#     392     """
#     393     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 394     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     395     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     396
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#     358   def _numpy(self):
#     359     try:
# --> 360       return self._numpy_internal()
#     361     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#     362       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
history_filename = basefilename +'-History.png'
plot_history(history_filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f3be54f50b75> in <cell line: 2>()
#       1 history_filename = basefilename +'-History.png'
# ----> 2 plot_history(history_filename)
#
# <ipython-input-5-1ffb6b1a840b> in plot_history(filename)
#      97     # Plot training & validation loss values
#      98     plt.subplot(1, 2, 1)
# ---> 99     plt.plot(history.history['loss'])
#     100     plt.plot(history.history['val_loss'])
#     101     plt.title('Model Loss')
#
# NameError: name 'history' is not defined

# %% [markdown]
# # Calcutale F1 and other metrics

# %%
for l_ratio in [0.25]:

    basefilename = 'Apple13-2Path5-NEW-LAB-m4-' + str(l_ratio)

    best_result_file_name = basefilename+'-best_result.hdf5'

    print('Best Model Results: '+basefilename)

    model = tf.keras.models.load_model(
        best_result_file_name,
        custom_objects={'CopyChannels': cai.layers.CopyChannels}
    )

    pred_y = model.predict(test_x)
    #         print("Predicted Shape:", pred_y.shape)
    pred_classes_y = np.array(list(np.argmax(pred_y, axis=1)))
    test_classes_y = np.array(list(np.argmax(test_y, axis=1)))
    #         print("Pred classes shape:",pred_classes_y.shape)
    #         print("Test classes shape:",test_classes_y.shape)
    report = classification_report(test_classes_y, pred_classes_y, digits=4)
    print(report)
# Out:
# Best Model Results: Apple13-2Path5-NEW-LAB-m4-0.25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-0fae6e88df74> in <cell line: 1>()
#      12     )
#      13
# ---> 14     pred_y = model.predict(test_x)
#      15     #         print("Predicted Shape:", pred_y.shape)
#      16     pred_classes_y = np.array(list(np.argmax(pred_y, axis=1)))
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2618                     )
#    2619
# -> 2620             data_handler = data_adapter.get_data_handler(
#    2621                 x=x,
#    2622                 batch_size=batch_size,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1686             return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1687         return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1688     return DataHandler(*args, **kwargs)
#    1689
#    1690
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1290
#    1291         adapter_cls = select_data_adapter(x, y)
# -> 1292         self._adapter = adapter_cls(
#    1293             x,
#    1294             y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     251     ):
#     252         super().__init__(x, y, **kwargs)
# --> 253         x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     254         sample_weight_modes = broadcast_sample_weight_modes(
#     255             sample_weights, sample_weight_modes
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in _process_tensorlike(inputs)
#    1161         return x
#    1162
# -> 1163     inputs = tf.nest.map_structure(_convert_single_tensor, inputs)
#    1164     return tf.__internal__.nest.list_to_tuple(inputs)
#    1165
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     629     ValueError: If wrong keyword arguments are provided.
#     630   """
# --> 631   return nest_util.map_structure(
#     632       nest_util.Modality.CORE, func, *structure, **kwargs
#     633   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in map_structure(modality, func, *structure, **kwargs)
#    1064   """
#    1065   if modality == Modality.CORE:
# -> 1066     return _tf_core_map_structure(func, *structure, **kwargs)
#    1067   elif modality == Modality.DATA:
#    1068     return _tf_data_map_structure(func, *structure, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in _tf_core_map_structure(func, *structure, **kwargs)
#    1104   return _tf_core_pack_sequence_as(
#    1105       structure[0],
# -> 1106       [func(*x) for x in entries],
#    1107       expand_composites=expand_composites,
#    1108   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in <listcomp>(.0)
#    1104   return _tf_core_pack_sequence_as(
#    1105       structure[0],
# -> 1106       [func(*x) for x in entries],
#    1107       expand_composites=expand_composites,
#    1108   )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/data_adapter.py in _convert_single_tensor(x)
#    1156             if issubclass(x.dtype.type, np.floating):
#    1157                 dtype = backend.floatx()
# -> 1158             return tf.convert_to_tensor(x, dtype=dtype)
#    1159         elif _is_scipy_sparse(x):
#    1160             return _scipy_sparse_to_sparse_tensor(x)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/errors_impl.py in __init__(self, node_def, op, message, *args)
#     460   """
#     461
# --> 462   def __init__(self, node_def, op, message, *args):
#     463     """Creates an `InternalError`."""
#     464     super(InternalError, self).__init__(node_def, op, message, INTERNAL, *args)
#
# KeyboardInterrupt:

# %% [markdown]
# # Confusion Matrix

# %%
for l_ratio in [0.25]:

    basefilename = 'Apple13-2Path5-NEW-LAB-m4-' + str(l_ratio)

    best_result_file_name = basefilename+'-best_result.hdf5'

    print('Best Model Results: '+basefilename)
    model = tf.keras.models.load_model(
        best_result_file_name,
        custom_objects={'CopyChannels': cai.layers.CopyChannels}
    )

    # Make predictions
    y_pred_prob = model.predict(test_x)
    y_pred = np.argmax(y_pred_prob, axis=1)

    # Create the confusion matrix
    cm = confusion_matrix(np.argmax(test_y, axis=1), y_pred)

    # Visualize the confusion matrix using seaborn
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=False, fmt='d', cmap='Blues', cbar=False,
                xticklabels='', yticklabels='')
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')

    figfilename = basefilename+'-CF.png'
    plt.savefig(figfilename, bbox_inches='tight')

    plt.show()
# Out:
# Best Model Results: Apple13-2Path5-NEW-LAB-m4-0.25
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-20-b5fd7876db7a> in <cell line: 1>()
#      12
#      13     # Make predictions
# ---> 14     y_pred_prob = model.predict(test_x)
#      15     y_pred = np.argmax(y_pred_prob, axis=1)
#      16
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     101       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     102   ctx.ensure_initialized()
# --> 103   return ops.EagerTensor(value, ctx.device_name, dtype)
#     104
#     105
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %%
def top_k_accuracy(y_true, y_pred, k=5):
    """
    Calculate top-k accuracy.

    Parameters:
    - y_true: True labels (ground truth)
    - y_pred: Predicted labels (probabilities or scores)
    - k: Top-k value (default is 5)

    Returns:
    - Top-k accuracy
    """
    top_k = np.argsort(y_pred, axis=-1)[:, -k:]
    correct = np.argmax(y_true, axis=-1)
    matches = np.any(top_k == correct[:, np.newaxis], axis=-1)
    accuracy = np.mean(matches)
    return accuracy

# %%
for l_ratio in [0.25]:

    basefilename = 'Apple13-2Path5-NEW-LAB-m4-' + str(l_ratio)

    best_result_file_name = basefilename+'-best_result.hdf5'

    print('Best Model Results: '+basefilename)
    model = tf.keras.models.load_model(
        best_result_file_name,
        custom_objects={'CopyChannels': cai.layers.CopyChannels}
    )

    # Make predictions
    y_pred = model.predict(test_x)
    y_pred = np.argmax(y_pred, axis=1)


top_k_accuracy(y_true, y_pred, k=5)
# Out:
# Best Model Results: Apple13-2Path5-NEW-LAB-m4-0.25
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-19-0799348a0cfb> in <cell line: 1>()
#      12
#      13     # Make predictions
# ---> 14     y_pred = model.predict(test_x)
#      15     y_pred = np.argmax(y_pred, axis=1)
#      16
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     101       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     102   ctx.ensure_initialized()
# --> 103   return ops.EagerTensor(value, ctx.device_name, dtype)
#     104
#     105
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.
